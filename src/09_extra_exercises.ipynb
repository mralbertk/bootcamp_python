# %% [markdown]
# # Additional Exercises
# These are extra exercises taken from previous iterations of this course. They are in no particular order of difficulty.

# %% [markdown]
# ## Numeric Types

# %% [markdown]
# ### Compound Interest
# Caluclate the balance of a savings account after n years of accumulated interested, compounded anually.
#
# Formula: $$\text{Balance} = \text{Principal} \times (1 + \text{Rate})^{\text{Years}}$$

# %%
# Write your function here
def compound_interest(principal: float, rate: float, years: int) -> int:
    pass

# %%
# Test your solution
sample_1 = (1000, 0.05, 10)
sample_2 = (500, 0.08, 5)

result_1 = compound_interest(*sample_1)
result_2 = compound_interest(*sample_2)

print(result_1)  # 1628
print(result_2)  # 734

# %% [markdown]
# ## Conditional Execution

# %% [markdown]
# ### Age Groups
# Categorize a person based on their age:
#
# - Younger than 13 -> 'child'
# - 13 to 19 -> `teenager`
# - 20 and older -> `adult`

# %%
# Write your function here
def get_age_group(age: int) -> str:
    pass

# %%
# Test your solution
result_1 = get_age_group(10)
result_2 = get_age_group(15)
result_3 = get_age_group(25)

print(result_1)  # child
print(result_2)  # teenager
print(result_3)  # adult

# %% [markdown]
# ## Sequences

# %% [markdown]
# ### Every Other One
# Take a list as input and return a new list that contains every other element of the original list, beginning with the first.

# %%
# Write your function here
def get_every_other_element(original_list: list) -> list:
    pass

# %%
# Test your solution
sample_1 = [0, 1, 2, 3, 4, 5]
sample_2 = ["a", "b", "c", "d"]

result_1 = get_every_other_element(sample_1)
result_2 = get_every_other_element(sample_2)

print(result_1)  # [0, 2, 4]
print(result_2)  # ["a", "c"]

# %% [markdown]
# ## Iteration

# %% [markdown]
# ### Factorial
# Write a function to caluclate the factorial $n!$ of any non-negative number. Raise a value error if the input is negative.

# %%
# Write your code here
def factorial(num: int) -> int:
    pass

# %%
# Test your code here
result_1 = factorial(5) 
result_2 = factorial(7)
# result_3 = factorial(-1) # <- Un-comment this line to raise the value error

print(result_1)  # 120
print(result_2)  # 5040

# %% [markdown]
# ## Unordered Collections

# %% [markdown]
# ### Check Uniqueness
# Write a function that is able to count the number of unique elements in any sequence.

# %%
# Write your code here
from typing import Sequence

def count_uniques(seq: Sequence) -> int:
    pass

# %%
# Test your solution
sample_1 = [0, 0, 1, 4, 3, 4]
sample_2 = ("a", "f", "z", 4, 4, "a", "hello world")

result_1 = count_uniques(sample_1)
result_2 = count_uniques(sample_2)

print(result_1) # 4
print(result_2) # 5

# %% [markdown]
# ## Advanced Iteration

# %% [markdown]
# ### Even Squares
# Create a function that takes as input a list of integers and resturns a list of squared integers, only including the squared numbers that are even.
#
# If any bad input is detected (i.e. a non-integer value) return an empty list.

# %%
# Write your code here
def even_squares(nums: list[int]) -> list[int]:
    pass

# %%
# Test your solution here
sample_1 = [1, 2, 3, 4, 5, 6]
sample_2 = [1, 3, 5]
sample_3 = [1, 2, "three"]

result_1 = even_squares(sample_1)
result_2 = even_squares(sample_2)
result_3 = even_squares(sample_3)

print(result_1)  # [4, 16, 36]
print(result_2)  # []
print(result_3)  # []

# %% [markdown]
# ## Advanced Functions

# %% [markdown]
# ### Safe Integer Conversion
# Write a function that converts safely to integer value. If bad input is given, the function should return `0` instead of raising an error.

# %%
# Write your function here
from typing import Any

def safe_to_int(num: Any) -> int:
    pass

# %%
# Test your code here
result_1 = safe_to_int("42")
result_2 = safe_to_int("forty_two")
result_3 = safe_to_int(None)

print(result_1)  # 42
print(result_2)  # 0
print(result_3)  # 0
